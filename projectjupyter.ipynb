# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy.stats import norm
from scipy.stats import probplot

# %%
df = pd.read_csv("stats.csv")

# %%
df[['USG%','MIN%','VI']]
# Out:
#      USG%  MIN%    VI
# 0    13.6  63.8   7.4
# 1    12.6  59.4   4.2
# 2    21.4  43.4   7.1
# 3    32.0  81.6  10.5
# 4    18.4  78.2   8.4
# ..    ...   ...   ...
# 207  60.0   4.3   0.0
# 208  18.2  20.4   0.0
# 209  20.9  10.2   0.0
# 210  28.7   3.3   0.0
# 211   0.0   3.3   0.0
#
# [212 rows x 3 columns]

# %%
df1 = df[['USG%','MIN%','VI']]

# %%
df.plot.scatter(x = 'VI',y = 'AST%')
df.plot.scatter(x = 'VI',y = 'TRB%')
df.plot.scatter(x = 'VI',y = 'EFG%')

# %%
df.plot.scatter(x='MIN%', y='USG%', c='VI', colormap='viridis')

# %%
df1.plot(kind='bar')
plt.grid(which='minor', linestyle='-', linewidth='0.5', color='white')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
